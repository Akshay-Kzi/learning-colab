# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-Kzi/learning-colab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Getting familiar with colab

# Get some information about the environment.
# !cat /etc/os-release
# Check available RAM.
# !free -h
# Check available disk space.
# !df -h
# Check the CPU.
# !lscpu
# Check the GPU (if available).
# !nvidia-smi
# Check Python version
# !python --version
# List installed packages
# !pip freeze
# Check current working directory
# !pwd
# List files in the current directory
# !ls -l

import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

import platform
print(f"Platform: {platform.platform()}")

import os
print(f"Current working directory: {os.getcwd()}")


# Example code to test execution
def hello():
  print("Hello, Colab!")

hello()
# Out:
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       703Mi       7.2Gi       1.0Mi       4.8Gi        11Gi
# Swap:             0B          0B          0B
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   33G   76G  31% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# tmpfs           6.4G   40K  6.4G   1% /var/colab
# /dev/sda1        77G   58G   20G  75% /etc/hosts
# ...
